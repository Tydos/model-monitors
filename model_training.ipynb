# %% [markdown]
# ### Setup MLFLow tracker

# %%
import mlflow
mlflow.set_tracking_uri("http://54.236.35.141:5000/")
mlflow.set_experiment("model-monitors")
# Out:
# <Experiment: artifact_location='s3://loan-prediction-artifacts/2', creation_time=1768247401172, experiment_id='2', last_update_time=1768247401172, lifecycle_stage='active', name='model-monitors', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %% [markdown]
# ## Train a model

# %%
import pandas as pd
df = pd.read_csv("dataset/train.csv")

# %%
df
# Out:
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 0            0       29367.99                 0.084           736
# 1            1       22108.02                 0.166           636
# 2            2       49566.20                 0.097           694
# 3            3       46858.25                 0.065           533
# 4            4       25496.70                 0.053           665
# ...        ...            ...                   ...           ...
# 593989  593989       23004.26                 0.152           703
# 593990  593990       35289.43                 0.105           559
# 593991  593991       47112.64                 0.072           675
# 593992  593992       76748.44                 0.067           740
# 593993  593993       48959.52                 0.096           752
#
#         loan_amount  interest_rate  gender marital_status education_level  \
# 0           2528.42          13.67  Female         Single     High School
# 1           4593.10          12.92    Male        Married        Master's
# 2          17005.15           9.76    Male         Single     High School
# 3           4682.48          16.10  Female         Single     High School
# 4          12184.43          10.21    Male        Married     High School
# ...             ...            ...     ...            ...             ...
# 593989     20958.37          10.92  Female         Single     High School
# 593990      3257.24          14.62    Male         Single      Bachelor's
# 593991       929.27          14.13  Female        Married      Bachelor's
# 593992     16290.40           9.87    Male         Single      Bachelor's
# 593993      7707.73          10.31    Male        Married     High School
#
#        employment_status        loan_purpose grade_subgrade  loan_paid_back
# 0          Self-employed               Other             C3             1.0
# 1               Employed  Debt consolidation             D3             0.0
# 2               Employed  Debt consolidation             C5             1.0
# 3               Employed  Debt consolidation             F1             1.0
# 4               Employed               Other             D1             1.0
# ...                  ...                 ...            ...             ...
# 593989          Employed            Business             C3             1.0
# 593990          Employed  Debt consolidation             F5             1.0
# 593991          Employed  Debt consolidation             C1             1.0
# 593992          Employed  Debt consolidation             B2             1.0
# 593993          Employed           Education             B3             1.0
#
# [593994 rows x 13 columns]

# %%
df.columns.tolist()
# Out:
# ['id',
#  'annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'gender',
#  'marital_status',
#  'education_level',
#  'employment_status',
#  'loan_purpose',
#  'grade_subgrade',
#  'loan_paid_back']

# %%
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()
num_cols = df.select_dtypes(exclude=["object"]).columns.tolist()
print("Categorical columns:", cat_cols)
print("Numerical columns:", num_cols)
# Out:
# Categorical columns: ['gender', 'marital_status', 'education_level', 'employment_status', 'loan_purpose', 'grade_subgrade']
# Numerical columns: ['id', 'annual_income', 'debt_to_income_ratio', 'credit_score', 'loan_amount', 'interest_rate', 'loan_paid_back']

# %%
df[cat_cols].describe()
# Out:
#         gender marital_status education_level employment_status  \
# count   593994         593994          593994            593994
# unique       3              4               5                 5
# top     Female         Single      Bachelor's          Employed
# freq    306175         288843          279606            450645
#
#               loan_purpose grade_subgrade
# count               593994         593994
# unique                   8             30
# top     Debt consolidation             C3
# freq                324695          58695

# %%
df[num_cols].describe()
# Out:
#                   id  annual_income  debt_to_income_ratio   credit_score  \
# count  593994.000000  593994.000000         593994.000000  593994.000000
# mean   296996.500000   48212.202976              0.120696     680.916009
# std    171471.442236   26711.942078              0.068573      55.424956
# min         0.000000    6002.430000              0.011000     395.000000
# 25%    148498.250000   27934.400000              0.072000     646.000000
# 50%    296996.500000   46557.680000              0.096000     682.000000
# 75%    445494.750000   60981.320000              0.156000     719.000000
# max    593993.000000  393381.740000              0.627000     849.000000
#
#          loan_amount  interest_rate  loan_paid_back
# count  593994.000000  593994.000000   593994.000000
# mean    15020.297629      12.356345        0.798820
# std      6926.530568       2.008959        0.400883
# min       500.090000       3.200000        0.000000
# 25%     10279.620000      10.990000        1.000000
# 50%     15000.220000      12.370000        1.000000
# 75%     18858.580000      13.680000        1.000000
# max     48959.950000      20.990000        1.000000

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=["loan_paid_back"])
y = df["loan_paid_back"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#target encoding
import category_encoders as ce
encoder = ce.TargetEncoder(cols=cat_cols)
X_train[cat_cols] = encoder.fit_transform(X_train[cat_cols], y_train)
X_test[cat_cols] = encoder.transform(X_test[cat_cols])
X_train
# Out:
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 29245    29245       46557.68                 0.196           637
# 272587  272587       36459.09                 0.092           703
# 464723  464723       58848.71                 0.077           659
# 135096  135096       49174.48                 0.078           739
# 39097    39097       54492.87                 0.093           691
# ...        ...            ...                   ...           ...
# 110268  110268       63490.98                 0.063           668
# 259178  259178       49384.88                 0.082           659
# 365838  365838       38999.04                 0.111           703
# 131932  131932       53920.25                 0.050           626
# 121958  121958       86771.66                 0.159           623
#
#         loan_amount  interest_rate    gender  marital_status  education_level  \
# 29245      17736.94          14.24  0.796315        0.797130         0.810160
# 272587      2746.15          12.98  0.796315        0.800087         0.789336
# 464723      7286.64          10.40  0.802359        0.799222         0.789336
# 135096     23461.42          10.94  0.802359        0.800087         0.810160
# 39097       8378.22           9.40  0.796315        0.799222         0.810160
# ...             ...            ...       ...             ...              ...
# 110268     16960.02           9.89  0.796315        0.800087         0.789336
# 259178      7862.06          12.62  0.796315        0.799222         0.810160
# 365838     19900.32          11.08  0.796315        0.799222         0.789336
# 131932     20306.85          14.29  0.796315        0.799222         0.803659
# 121958     16809.45           9.69  0.796315        0.799222         0.789336
#
#         employment_status  loan_purpose  grade_subgrade
# 29245            0.078334      0.797570        0.713594
# 272587           0.894382      0.811056        0.835771
# 464723           0.894382      0.797570        0.721923
# 135096           0.894382      0.824578        0.843676
# 39097            0.894382      0.797570        0.851439
# ...                   ...           ...             ...
# 110268           0.894382      0.797570        0.721923
# 259178           0.894382      0.778130        0.715089
# 365838           0.078334      0.797570        0.861390
# 131932           0.894382      0.800642        0.715089
# 121958           0.894382      0.797570        0.696941
#
# [415795 rows x 12 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
X_train.iloc[0].tolist()
# Out:
# [29245.0,
#  46557.68,
#  0.196,
#  637.0,
#  17736.94,
#  14.24,
#  0.796314823659536,
#  0.7971295060080107,
#  0.8101600329548193,
#  0.07833383003599184,
#  0.7975704405061509,
#  0.7135939741750359]

# %%
model.predict([X_train.iloc[0].tolist()])
# Out:
# d:\GitHub\model-monitors\onnx\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0.])

# %%
y_test
# Out:
# 404674    1.0
# 549728    1.0
# 125237    0.0
# 512666    1.0
# 101001    1.0
#          ...
# 213431    1.0
# 71672     1.0
# 565660    0.0
# 440849    1.0
# 262133    1.0
# Name: loan_paid_back, Length: 178199, dtype: float64

# %%
X_test
# Out:
#             id  annual_income  debt_to_income_ratio  credit_score  \
# 404674  404674       52470.61                 0.241           724
# 549728  549728       28424.82                 0.033           779
# 125237  125237       25229.55                 0.195           569
# 512666  512666       91612.58                 0.166           659
# 101001  101001       79712.79                 0.079           767
# ...        ...            ...                   ...           ...
# 213431  213431       38768.55                 0.130           683
# 71672    71672       25684.40                 0.042           753
# 565660  565660       14145.21                 0.087           667
# 440849  440849       20676.22                 0.084           674
# 262133  262133       58793.67                 0.179           724
#
#         loan_amount  interest_rate    gender  marital_status  education_level  \
# 404674     27172.82          13.35  0.796315        0.800087         0.832303
# 549728     15895.96          11.57  0.796315        0.800087         0.803659
# 125237     15216.06          13.83  0.802359        0.799222         0.803289
# 512666     13166.90          12.47  0.802359        0.799222         0.803289
# 101001     23642.37          11.23  0.796315        0.799222         0.789336
# ...             ...            ...       ...             ...              ...
# 213431      2280.72          13.15  0.796315        0.800087         0.810160
# 71672       6014.89          10.36  0.802359        0.799222         0.789336
# 565660      1352.92          12.94  0.802359        0.800087         0.789336
# 440849     26015.86          10.97  0.796315        0.799222         0.810160
# 262133     10248.58           9.73  0.802359        0.800087         0.789336
#
#         employment_status  loan_purpose  grade_subgrade
# 404674           0.894382      0.797570        0.851439
# 549728           0.894382      0.802576        0.936005
# 125237           0.894382      0.797570        0.633715
# 512666           0.894382      0.782000        0.733615
# 101001           0.894382      0.778130        0.915598
# ...                   ...           ...             ...
# 213431           0.894382      0.782000        0.835771
# 71672            0.894382      0.797570        0.936005
# 565660           0.078334      0.797570        0.721923
# 440849           0.894382      0.797570        0.851439
# 262133           0.894382      0.802576        0.835771
#
# [178199 rows x 12 columns]

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy on test set:", accuracy)

recall = recall_score(y_test, y_pred)
print("Recall on test set:", recall)

precision = precision_score(y_test, y_pred)
print("Precision on test set:", precision)
# Out:
# Accuracy on test set: 0.8480126151100735
# Recall on test set: 0.8993821339601131
# Precision on test set: 0.9090546980581834

# %%
mlflow.log_params({
    "model_type": "DecisionTreeClassifier",
    "random_state": 42,
    "test_size": 0.3,
    })
mlflow.log_metric("accuracy", accuracy)  
mlflow.log_metric("recall", recall)
mlflow.log_metric("precision", precision)

# %% [markdown]
# ## Model Saving

# %% [markdown]
# ### ONNX

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

#model input type
initial_type = [('float_input', FloatTensorType([None,  X.shape[1]]))]

#cxreate ONNX model
onx = convert_sklearn(
    model,
    initial_types=initial_type)

#write to disk
with open("model.onnx", "wb") as f:
    f.write(onx.SerializeToString())

# %% [markdown]
# ### Pickle

# %%
import pickle
with open("model.pkl","wb") as f:
    pickle.dump(model,f)

# %% [markdown]
# ### Version model in MLFlow registry

# %%
mlflow.sklearn.log_model(model, "model")
mlflow.onnx.log_model(onnx_model=onx, artifact_path="onnx-model")
mlflow.end_run()
# Out:
# 2026/01/12 14:05:35 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/01/12 14:05:49 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run painted-snail-143 at: http://54.236.35.141:5000/#/experiments/2/runs/8ba77eab225b4e3e92fe2ec9b801ec9a
# 🧪 View experiment at: http://54.236.35.141:5000/#/experiments/2
